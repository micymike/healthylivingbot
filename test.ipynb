# %%
# %pip install pypdf
# %pip install sentence-transformers
# %pip install llama_index
# %pip install langchain
# %pip install torch
# %pip install huggingface_hub
# Out:
# Requirement already satisfied: pypdf in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (4.2.0)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from pypdf) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: sentence-transformers in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (2.6.0)
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from sentence-transformers) (4.41.2)
# Requirement already satisfied: tqdm in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from sentence-transformers) (2.3.1)
# Requirement already satisfied: numpy in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from sentence-transformers) (1.24.4)
# Requirement already satisfied: scikit-learn in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from sentence-transformers) (1.3.2)
# Requirement already satisfied: scipy in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: huggingface-hub>=0.15.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from sentence-transformers) (0.23.3)
# Requirement already satisfied: Pillow in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from sentence-transformers) (10.3.0)
# Requirement already satisfied: filelock in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2024.6.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.12.1)
# Requirement already satisfied: networkx in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from torch>=1.11.0->sentence-transformers) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (2024.5.15)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.4.3)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence-transformers) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.11.0->sentence-transformers) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting llama_index
#   Downloading llama_index-0.10.44-py3-none-any.whl.metadata (11 kB)
# Collecting llama-index-agent-openai<0.3.0,>=0.1.4 (from llama_index)
#   Downloading llama_index_agent_openai-0.2.7-py3-none-any.whl.metadata (678 bytes)
# Collecting llama-index-cli<0.2.0,>=0.1.2 (from llama_index)
#   Downloading llama_index_cli-0.1.12-py3-none-any.whl.metadata (1.5 kB)
# Collecting llama-index-core==0.10.44 (from llama_index)
#   Downloading llama_index_core-0.10.44-py3-none-any.whl.metadata (2.4 kB)
# Collecting llama-index-embeddings-openai<0.2.0,>=0.1.5 (from llama_index)
#   Downloading llama_index_embeddings_openai-0.1.10-py3-none-any.whl.metadata (604 bytes)
# Collecting llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 (from llama_index)
#   Downloading llama_index_indices_managed_llama_cloud-0.1.6-py3-none-any.whl.metadata (3.8 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama_index)
#   Downloading llama_index_legacy-0.9.48-py3-none-any.whl.metadata (8.5 kB)
# Collecting llama-index-llms-openai<0.2.0,>=0.1.13 (from llama_index)
#   Downloading llama_index_llms_openai-0.1.22-py3-none-any.whl.metadata (559 bytes)
# Collecting llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 (from llama_index)
#   Downloading llama_index_multi_modal_llms_openai-0.1.6-py3-none-any.whl.metadata (677 bytes)
# Collecting llama-index-program-openai<0.2.0,>=0.1.3 (from llama_index)
#   Downloading llama_index_program_openai-0.1.6-py3-none-any.whl.metadata (715 bytes)
# Collecting llama-index-question-gen-openai<0.2.0,>=0.1.2 (from llama_index)
#   Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl.metadata (785 bytes)
# Collecting llama-index-readers-file<0.2.0,>=0.1.4 (from llama_index)
#   Downloading llama_index_readers_file-0.1.25-py3-none-any.whl.metadata (5.4 kB)
# Collecting llama-index-readers-llama-parse<0.2.0,>=0.1.2 (from llama_index)
#   Downloading llama_index_readers_llama_parse-0.1.4-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.44->llama_index) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (3.9.5)
# Requirement already satisfied: dataclasses-json in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (0.5.14)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (1.2.14)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core==0.10.44->llama_index)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (2024.6.0)
# Requirement already satisfied: httpx in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (0.27.0)
# Collecting llamaindex-py-client<0.2.0,>=0.1.18 (from llama-index-core==0.10.44->llama_index)
#   Downloading llamaindex_py_client-0.1.19-py3-none-any.whl.metadata (760 bytes)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (3.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (3.8.1)
# Requirement already satisfied: numpy in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (1.24.4)
# Collecting openai>=1.1.0 (from llama-index-core==0.10.44->llama_index)
#   Downloading openai-1.34.0-py3-none-any.whl.metadata (21 kB)
# Collecting pandas (from llama-index-core==0.10.44->llama_index)
#   Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (10.3.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (8.3.0)
# Collecting tiktoken>=0.3.3 (from llama-index-core==0.10.44->llama_index)
#   Using cached tiktoken-0.7.0-cp38-cp38-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (1.16.0)
# Collecting beautifulsoup4<5.0.0,>=4.12.3 (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index) (4.2.0)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse<0.5.0,>=0.4.0 (from llama-index-readers-llama-parse<0.2.0,>=0.1.2->llama_index)
#   Downloading llama_parse-0.4.4-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama_index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama_index) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama_index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama_index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama_index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama_index) (4.0.3)
# Collecting soupsieve>1.2 (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama_index)
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pydantic>=1.10 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core==0.10.44->llama_index) (1.10.15)
# Requirement already satisfied: anyio in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core==0.10.44->llama_index) (4.4.0)
# Requirement already satisfied: certifi in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core==0.10.44->llama_index) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core==0.10.44->llama_index) (1.0.5)
# Requirement already satisfied: idna in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core==0.10.44->llama_index) (3.7)
# Requirement already satisfied: sniffio in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core==0.10.44->llama_index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from httpcore==1.*->httpx->llama-index-core==0.10.44->llama_index) (0.14.0)
# Requirement already satisfied: click in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.44->llama_index) (8.1.7)
# Requirement already satisfied: joblib in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.44->llama_index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.44->llama_index) (2024.5.15)
# Collecting distro<2,>=1.7.0 (from openai>=1.1.0->llama-index-core==0.10.44->llama_index)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests>=2.31.0->llama-index-core==0.10.44->llama_index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests>=2.31.0->llama-index-core==0.10.44->llama_index) (2.2.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.44->llama_index) (3.0.3)
# Requirement already satisfied: colorama in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core==0.10.44->llama_index) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core==0.10.44->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from dataclasses-json->llama-index-core==0.10.44->llama_index) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core==0.10.44->llama_index) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core==0.10.44->llama_index) (2024.1)
# Collecting tzdata>=2022.1 (from pandas->llama-index-core==0.10.44->llama_index)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from anyio->httpx->llama-index-core==0.10.44->llama_index) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core==0.10.44->llama_index) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core==0.10.44->llama_index) (1.16.0)
# Downloading llama_index-0.10.44-py3-none-any.whl (6.8 kB)
# Downloading llama_index_core-0.10.44-py3-none-any.whl (15.4 MB)
#    ---------------------------------------- 0.0/15.4 MB ? eta -:--:--
#    ---------------------------------------- 0.2/15.4 MB ? eta -:--:--
#     --------------------------------------- 0.2/15.4 MB 1.0 MB/s eta 0:00:15
#     --------------------------------------- 0.3/15.4 MB 1.1 MB/s eta 0:00:14
#    - -------------------------------------- 0.4/15.4 MB 1.2 MB/s eta 0:00:13
#    -- ------------------------------------- 0.9/15.4 MB 1.6 MB/s eta 0:00:10
#    -- ------------------------------------- 1.0/15.4 MB 1.6 MB/s eta 0:00:09
#    --- ------------------------------------ 1.4/15.4 MB 1.8 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.7/15.4 MB 1.9 MB/s eta 0:00:08
#    ----- ---------------------------------- 2.0/15.4 MB 2.1 MB/s eta 0:00:07
#    ------ --------------------------------- 2.3/15.4 MB 2.2 MB/s eta 0:00:06
#    ------ --------------------------------- 2.6/15.4 MB 2.3 MB/s eta 0:00:06
#    ------- -------------------------------- 2.9/15.4 MB 2.5 MB/s eta 0:00:06
#    -------- ------------------------------- 3.3/15.4 MB 2.6 MB/s eta 0:00:05
#    --------- ------------------------------ 3.8/15.4 MB 2.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 4.3/15.4 MB 2.9 MB/s eta 0:00:04
#    ------------ --------------------------- 4.8/15.4 MB 3.1 MB/s eta 0:00:04
#    ------------- -------------------------- 5.2/15.4 MB 3.0 MB/s eta 0:00:04
#    -------------- ------------------------- 5.4/15.4 MB 3.1 MB/s eta 0:00:04
#    --------------- ------------------------ 6.1/15.4 MB 3.3 MB/s eta 0:00:03
#    ----------------- ---------------------- 6.9/15.4 MB 3.5 MB/s eta 0:00:03
#    ------------------ --------------------- 7.1/15.4 MB 3.5 MB/s eta 0:00:03
#    ------------------- -------------------- 7.5/15.4 MB 3.5 MB/s eta 0:00:03
#    -------------------- ------------------- 7.7/15.4 MB 3.6 MB/s eta 0:00:03
#    --------------------- ------------------ 8.3/15.4 MB 3.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 8.9/15.4 MB 3.8 MB/s eta 0:00:02
#    ------------------------ --------------- 9.5/15.4 MB 3.9 MB/s eta 0:00:02
#    -------------------------- ------------- 10.1/15.4 MB 4.0 MB/s eta 0:00:02
#    --------------------------- ------------ 10.4/15.4 MB 4.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.9/15.4 MB 4.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.4/15.4 MB 5.0 MB/s eta 0:00:01
#    ------------------------------ --------- 11.8/15.4 MB 5.2 MB/s eta 0:00:01
#    ------------------------------- -------- 12.2/15.4 MB 5.3 MB/s eta 0:00:01
#    -------------------------------- ------- 12.6/15.4 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.3/15.4 MB 5.6 MB/s eta 0:00:01
#    ------------------------------------ --- 14.0/15.4 MB 5.8 MB/s eta 0:00:01
#    ------------------------------------- -- 14.3/15.4 MB 5.7 MB/s eta 0:00:01
#    -------------------------------------- - 14.8/15.4 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  15.4/15.4 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  15.4/15.4 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.4/15.4 MB 5.8 MB/s eta 0:00:00
# Downloading llama_index_agent_openai-0.2.7-py3-none-any.whl (12 kB)
# Downloading llama_index_cli-0.1.12-py3-none-any.whl (26 kB)
# Downloading llama_index_embeddings_openai-0.1.10-py3-none-any.whl (6.2 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.1.6-py3-none-any.whl (6.7 kB)
# Downloading llama_index_legacy-0.9.48-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------- ------------------------ 0.8/2.0 MB 16.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.5/2.0 MB 10.3 MB/s eta 0:00:01
#    ------------------------------------- -- 1.9/2.0 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 7.4 MB/s eta 0:00:00
# Downloading llama_index_llms_openai-0.1.22-py3-none-any.whl (11 kB)
# Downloading llama_index_multi_modal_llms_openai-0.1.6-py3-none-any.whl (5.8 kB)
# Downloading llama_index_program_openai-0.1.6-py3-none-any.whl (5.2 kB)
# Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl (2.9 kB)
# Downloading llama_index_readers_file-0.1.25-py3-none-any.whl (37 kB)
# Downloading llama_index_readers_llama_parse-0.1.4-py3-none-any.whl (2.5 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Downloading llama_parse-0.4.4-py3-none-any.whl (8.0 kB)
# Downloading llamaindex_py_client-0.1.19-py3-none-any.whl (141 kB)
#    ---------------------------------------- 0.0/141.9 kB ? eta -:--:--
#    ---------------------------------------- 141.9/141.9 kB 8.2 MB/s eta 0:00:00
# Downloading openai-1.34.0-py3-none-any.whl (325 kB)
#    ---------------------------------------- 0.0/325.5 kB ? eta -:--:--
#    --------------------------------------- 325.5/325.5 kB 10.2 MB/s eta 0:00:00
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Using cached tiktoken-0.7.0-cp38-cp38-win_amd64.whl (798 kB)
# Using cached pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: striprtf, dirtyjson, tzdata, soupsieve, distro, tiktoken, pandas, beautifulsoup4, openai, llamaindex-py-client, llama-index-legacy, llama-index-core, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama_index
# Successfully installed beautifulsoup4-4.12.3 dirtyjson-1.0.8 distro-1.9.0 llama-index-agent-openai-0.2.7 llama-index-cli-0.1.12 llama-index-core-0.10.44 llama-index-embeddings-openai-0.1.10 llama-index-indices-managed-llama-cloud-0.1.6 llama-index-legacy-0.9.48 llama-index-llms-openai-0.1.22 llama-index-multi-modal-llms-openai-0.1.6 llama-index-program-openai-0.1.6 llama-index-question-gen-openai-0.1.3 llama-index-readers-file-0.1.25 llama-index-readers-llama-parse-0.1.4 llama-parse-0.4.4 llama_index-0.10.44 llamaindex-py-client-0.1.19 openai-1.34.0 pandas-2.0.3 soupsieve-2.5 striprtf-0.0.26 tiktoken-0.7.0 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: langchain in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (0.2.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.6 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain) (0.2.6)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain) (0.2.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain) (0.1.77)
# Requirement already satisfied: numpy<2,>=1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain) (1.24.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain) (1.10.15)
# Requirement already satisfied: requests<3,>=2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain-core<0.3.0,>=0.2.6->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langchain-core<0.3.0,>=0.2.6->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.4)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from pydantic<3,>=1->langchain) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests<3,>=2->langchain) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.6->langchain) (3.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (2.3.1)
# Requirement already satisfied: filelock in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from torch) (2024.6.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: huggingface_hub in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (0.23.3)
# Requirement already satisfied: filelock in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from huggingface_hub) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from huggingface_hub) (2024.6.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from huggingface_hub) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: colorama in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests->huggingface_hub) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests->huggingface_hub) (2024.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install llama_index
# Out:
# Requirement already satisfied: llama_index in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (0.10.44)
# Requirement already satisfied: llama-index-agent-openai<0.3.0,>=0.1.4 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama_index) (0.2.7)
# Requirement already satisfied: llama-index-cli<0.2.0,>=0.1.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama_index) (0.1.12)
# Requirement already satisfied: llama-index-core==0.10.44 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama_index) (0.10.44)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.5 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama_index) (0.1.10)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama_index) (0.1.6)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama_index) (0.9.48)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.13 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama_index) (0.1.22)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama_index) (0.1.6)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.3 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama_index) (0.1.6)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama_index) (0.1.3)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.4 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama_index) (0.1.25)
# Requirement already satisfied: llama-index-readers-llama-parse<0.2.0,>=0.1.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama_index) (0.1.4)
# Requirement already satisfied: PyYAML>=6.0.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.44->llama_index) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (3.9.5)
# Requirement already satisfied: dataclasses-json in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (0.5.14)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (2024.6.0)
# Requirement already satisfied: httpx in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.18 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (0.1.19)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (3.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (3.8.1)
# Requirement already satisfied: numpy in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (1.24.4)
# Requirement already satisfied: openai>=1.1.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (1.34.0)
# Requirement already satisfied: pandas in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (2.0.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (10.3.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (8.3.0)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-core==0.10.44->llama_index) (1.16.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index) (4.12.3)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index) (4.2.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama_index) (0.0.26)
# Requirement already satisfied: llama-parse<0.5.0,>=0.4.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llama-index-readers-llama-parse<0.2.0,>=0.1.2->llama_index) (0.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama_index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama_index) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama_index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama_index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama_index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core==0.10.44->llama_index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama_index) (2.5)
# Requirement already satisfied: pydantic>=1.10 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core==0.10.44->llama_index) (1.10.15)
# Requirement already satisfied: anyio in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core==0.10.44->llama_index) (4.4.0)
# Requirement already satisfied: certifi in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core==0.10.44->llama_index) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core==0.10.44->llama_index) (1.0.5)
# Requirement already satisfied: idna in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core==0.10.44->llama_index) (3.7)
# Requirement already satisfied: sniffio in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from httpx->llama-index-core==0.10.44->llama_index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from httpcore==1.*->httpx->llama-index-core==0.10.44->llama_index) (0.14.0)
# Requirement already satisfied: click in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.44->llama_index) (8.1.7)
# Requirement already satisfied: joblib in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.44->llama_index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core==0.10.44->llama_index) (2024.5.15)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from openai>=1.1.0->llama-index-core==0.10.44->llama_index) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests>=2.31.0->llama-index-core==0.10.44->llama_index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from requests>=2.31.0->llama-index-core==0.10.44->llama_index) (2.2.1)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core==0.10.44->llama_index) (3.0.3)
# Requirement already satisfied: colorama in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core==0.10.44->llama_index) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core==0.10.44->llama_index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from dataclasses-json->llama-index-core==0.10.44->llama_index) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core==0.10.44->llama_index) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core==0.10.44->llama_index) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from pandas->llama-index-core==0.10.44->llama_index) (2024.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from anyio->httpx->llama-index-core==0.10.44->llama_index) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core==0.10.44->llama_index) (23.2)
# Requirement already satisfied: six>=1.5 in c:\users\mike\miniconda3\envs\mchatbot\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core==0.10.44->llama_index) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from llama_index import SimpleDirectoryReader, ServiceContext
#from llama_index.prompts.prompts import SimpleInputPrompt
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
import torch
import chromadb
from chromadb.utils import embedding_functions
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from llama_index import SimpleDirectoryReader, ServiceContext
#       2 #from llama_index.prompts.prompts import SimpleInputPrompt
#       3 from langchain.embeddings.huggingface import HuggingFaceEmbeddings
#
# ImportError: cannot import name 'SimpleDirectoryReader' from 'llama_index' (unknown location)
